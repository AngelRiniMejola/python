# %%
age=int(input("Enter Your AGE:"))
# Out:
# Enter Your AGE: 18

# %%
if(age==18):
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter Your AGE:"))
# Out:
# Enter Your AGE: 5

# %%
if(age<18):
    print("children")
else:
    print("adult")
# Out:
# children
